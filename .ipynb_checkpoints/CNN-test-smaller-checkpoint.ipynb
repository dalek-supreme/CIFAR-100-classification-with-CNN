# %% [markdown]
# # Classification on CIFAR-100 dataset with CNN

# %% [markdown]
# **Xingzhi Sun**

# %% [markdown]
# code modified from: NELSONZHAO,https://github.com/NELSONZHAO/zhihu/tree/master/cifar_cnn

# %% [markdown]
# ## Preparations

# %% [markdown]
# ### Load the environment

# %%
import numpy as np
import tensorflow as tf
import pickle
import matplotlib.pyplot as plt
import warnings

warnings.filterwarnings("ignore")
# %matplotlib inline

# %% [markdown]
# ### Load training set

# %%
data_path='cifar-100-python/'
with open(data_path+'train', 'rb') as f1:
    data = pickle.load(f1, encoding='latin1')

# %% [markdown]
# ### see data type

# %%
data.keys()
# Out:
# dict_keys(['filenames', 'batch_label', 'fine_labels', 'coarse_labels', 'data'])
# dict_keys(['filenames', 'batch_label', 'fine_labels', 'coarse_labels', 'data'])

# %%
data['batch_label']
# Out:
# 'training batch 1 of 1'
# 'training batch 1 of 1'

# %%
data['coarse_labels']
# Out:
# [11,
#  15,
#  4,
#  14,
#  1,
#  5,
#  18,
#  3,
#  10,
#  11,
#  5,
#  17,
#  2,
#  9,
#  10,
#  5,
#  18,
#  8,
#  16,
#  10,
#  16,
#  17,
#  2,
#  5,
#  17,
#  6,
#  12,
#  17,
#  8,
#  12,
#  18,
#  9,
#  17,
#  16,
#  11,
#  5,
#  19,
#  14,
#  7,
#  6,
#  15,
#  13,
#  10,
#  8,
#  17,
#  9,
#  14,
#  18,
#  19,
#  15,
#  1,
#  7,
#  5,
#  3,
#  10,
#  7,
#  17,
#  6,
#  14,
#  17,
#  16,
#  0,
#  0,
#  8,
#  4,
#  14,
#  4,
#  10,
#  15,
#  4,
#  2,
#  16,
#  11,
#  19,
#  16,
#  7,
#  19,
#  14,
#  10,
#  8,
#  5,
#  12,
#  12,
#  11,
#  10,
#  8,
#  12,
#  13,
#  10,
#  7,
#  14,
#  11,
#  14,
#  19,
#  0,
#  4,
#  12,
#  13,
#  1,
#  15,
#  0,
#  5,
#  0,
#  8,
#  3,
#  15,
#  4,
#  19,
#  17,
#  6,
#  17,
#  12,
#  6,
#  0,
#  14,
#  10,
#  9,
#  11,
#  6,
#  10,
#  12,
#  1,
#  14,
#  4,
#  8,
#  1,
#  2,
#  12,
#  4,
#  12,
#  18,
#  17,
#  5,
#  0,
#  6,
#  0,
#  12,
#  11,
#  9,
#  5,
#  17,
#  2,
#  14,
#  12,
#  5,
#  0,
#  13,
#  12,
#  16,
#  4,
#  13,
#  0,
#  18,
#  15,
#  10,
#  15,
#  5,
#  13,
#  1,
#  14,
#  12,
#  3,
#  19,
#  1,
#  2,
#  15,
#  5,
#  2,
#  3,
#  12,
#  16,
#  0,
#  11,
#  12,
#  2,
#  0,
#  4,
#  15,
#  7,
#  9,
#  11,
#  14,
#  11,
#  3,
#  13,
#  13,
#  19,
#  13,
#  14,
#  8,
#  14,
#  1,
#  16,
#  9,
#  16,
#  18,
#  19,
#  6,
#  5,
#  19,
#  5,
#  1,
#  14,
#  14,
#  10,
#  12,
#  8,
#  7,
#  10,
#  9,
#  16,
#  19,
#  9,
#  13,
#  16,
#  11,
#  13,
#  9,
#  5,
#  18,
#  3,
#  2,
#  5,
#  5,
#  11,
#  2,
#  5,
#  3,
#  14,
#  19,
#  18,
#  18,
#  13,
#  12,
#  19,
#  11,
#  13,
#  5,
#  15,
#  5,
#  18,
#  6,
#  14,
#  11,
#  3,
#  17,
#  2,
#  16,
#  5,
#  5,
#  8,
#  18,
#  18,
#  4,
#  14,
#  10,
#  10,
#  19,
#  17,
#  14,
#  14,
#  0,
#  8,
#  5,
#  12,
#  12,
#  7,
#  14,
#  12,
#  17,
#  4,
#  1,
#  15,
#  14,
#  2,
#  10,
#  18,
#  17,
#  11,
#  9,
#  12,
#  3,
#  1,
#  4,
#  1,
#  6,
#  18,
#  15,
#  7,
#  6,
#  7,
#  19,
#  16,
#  16,
#  9,
#  16,
#  12,
#  13,
#  18,
#  4,
#  10,
#  13,
#  8,
#  19,
#  4,
#  15,
#  11,
#  3,
#  14,
#  7,
#  8,
#  4,
#  8,
#  1,
#  2,
#  3,
#  8,
#  4,
#  2,
#  6,
#  9,
#  10,
#  0,
#  14,
#  2,
#  6,
#  12,
#  12,
#  3,
#  12,
#  2,
#  4,
#  5,
#  12,
#  12,
#  1,
#  2,
#  8,
#  8,
#  9,
#  16,
#  5,
#  8,
#  15,
#  8,
#  9,
#  1,
#  17,
#  10,
#  17,
#  6,
#  11,
#  2,
#  4,
#  11,
#  14,
#  16,
#  12,
#  9,
#  10,
#  8,
#  16,
#  2,
#  13,
#  13,
#  16,
#  0,
#  14,
#  11,
#  11,
#  18,
#  9,
#  1,
#  10,
#  5,
#  13,
#  11,
#  7,
#  18,
#  4,
#  0,
#  19,
#  14,
#  8,
#  19,
#  3,
#  8,
#  14,
#  6,
#  0,
#  18,
#  15,
#  18,
#  7,
#  1,
#  8,
#  16,
#  17,
#  3,
#  15,
#  0,
#  14,
#  4,
#  5,
#  18,
#  5,
#  17,
#  7,
#  18,
#  6,
#  8,
#  13,
#  11,
#  7,
#  4,
#  9,
#  10,
#  19,
#  17,
#  2,
#  7,
#  18,
#  13,
#  10,
#  5,
#  17,
#  1,
#  18,
#  8,
#  7,
#  11,
#  9,
#  16,
#  3,
#  10,
#  12,
#  10,
#  7,
#  0,
#  12,
#  7,
#  4,
#  17,
#  10,
#  12,
#  2,
#  15,
#  13,
#  12,
#  1,
#  6,
#  18,
#  18,
#  15,
#  9,
#  14,
#  2,
#  13,
#  8,
#  4,
#  2,
#  12,
#  10,
#  16,
#  6,
#  18,
#  2,
#  10,
#  3,
#  3,
#  15,
#  17,
#  2,
#  3,
#  8,
#  6,
#  11,
#  19,
#  5,
#  10,
#  19,
#  7,
#  7,
#  8,
#  5,
#  11,
#  0,
#  17,
#  0,
#  19,
#  14,
#  8,
#  7,
#  14,
#  10,
#  19,
#  5,
#  4,
#  2,
#  15,
#  19,
#  17,
#  1,
#  19,
#  13,
#  0,
#  9,
#  7,
#  1,
#  6,
#  2,
#  2,
#  10,
#  4,
#  16,
#  10,
#  10,
#  17,
#  19,
#  5,
#  11,
#  19,
#  9,
#  8,
#  2,
#  13,
#  10,
#  15,
#  4,
#  11,
#  8,
#  8,
#  3,
#  11,
#  10,
#  6,
#  16,
#  12,
#  6,
#  13,
#  18,
#  10,
#  6,
#  1,
#  3,
#  0,
#  1,
#  0,
#  4,
#  1,
#  10,
#  5,
#  13,
#  19,
#  19,
#  19,
#  13,
#  17,
#  4,
#  14,
#  18,
#  16,
#  14,
#  14,
#  0,
#  16,
#  9,
#  17,
#  10,
#  6,
#  19,
#  6,
#  2,
#  3,
#  10,
#  18,
#  18,
#  11,
#  14,
#  1,
#  14,
#  16,
#  2,
#  10,
#  18,
#  12,
#  4,
#  4,
#  9,
#  13,
#  4,
#  2,
#  4,
#  11,
#  16,
#  1,
#  3,
#  14,
#  14,
#  14,
#  5,
#  11,
#  17,
#  19,
#  5,
#  9,
#  7,
#  2,
#  9,
#  0,
#  17,
#  6,
#  8,
#  1,
#  14,
#  16,
#  8,
#  10,
#  7,
#  10,
#  6,
#  7,
#  13,
#  15,
#  9,
#  2,
#  6,
#  12,
#  1,
#  17,
#  19,
#  4,
#  5,
#  19,
#  13,
#  6,
#  6,
#  14,
#  0,
#  19,
#  13,
#  5,
#  13,
#  1,
#  17,
#  16,
#  4,
#  6,
#  16,
#  2,
#  2,
#  0,
#  10,
#  10,
#  19,
#  13,
#  1,
#  14,
#  4,
#  7,
#  3,
#  15,
#  15,
#  18,
#  8,
#  16,
#  14,
#  6,
#  5,
#  0,
#  3,
#  4,
#  14,
#  19,
#  6,
#  19,
#  2,
#  15,
#  15,
#  8,
#  10,
#  4,
#  18,
#  11,
#  16,
#  4,
#  11,
#  17,
#  6,
#  17,
#  16,
#  1,
#  14,
#  9,
#  18,
#  13,
#  9,
#  16,
#  12,
#  3,
#  9,
#  7,
#  0,
#  6,
#  17,
#  9,
#  6,
#  14,
#  11,
#  6,
#  6,
#  15,
#  12,
#  4,
#  7,
#  1,
#  16,
#  9,
#  15,
#  2,
#  19,
#  6,
#  14,
#  18,
#  12,
#  0,
#  11,
#  2,
#  16,
#  11,
#  15,
#  17,
#  1,
#  8,
#  1,
#  5,
#  19,
#  2,
#  10,
#  2,
#  14,
#  19,
#  8,
#  2,
#  8,
#  14,
#  18,
#  5,
#  16,
#  3,
#  12,
#  2,
#  4,
#  9,
#  6,
#  10,
#  4,
#  15,
#  13,
#  19,
#  4,
#  3,
#  11,
#  7,
#  6,
#  9,
#  6,
#  14,
#  2,
#  15,
#  15,
#  13,
#  11,
#  4,
#  16,
#  9,
#  17,
#  12,
#  15,
#  5,
#  9,
#  3,
#  0,
#  19,
#  16,
#  18,
#  18,
#  17,
#  2,
#  4,
#  12,
#  18,
#  4,
#  15,
#  12,
#  14,
#  4,
#  12,
#  19,
#  7,
#  12,
#  0,
#  16,
#  19,
#  6,
#  7,
#  18,
#  3,
#  8,
#  17,
#  9,
#  9,
#  8,
#  12,
#  10,
#  5,
#  12,
#  13,
#  11,
#  10,
#  0,
#  13,
#  4,
#  10,
#  0,
#  0,
#  12,
#  9,
#  14,
#  12,
#  17,
#  19,
#  12,
#  12,
#  10,
#  16,
#  13,
#  2,
#  7,
#  18,
#  16,
#  16,
#  13,
#  3,
#  10,
#  9,
#  13,
#  17,
#  16,
#  17,
#  19,
#  19,
#  11,
#  5,
#  16,
#  14,
#  10,
#  16,
#  6,
#  1,
#  14,
#  4,
#  9,
#  13,
#  2,
#  16,
#  12,
#  0,
#  9,
#  1,
#  11,
#  2,
#  5,
#  19,
#  4,
#  7,
#  11,
#  6,
#  14,
#  14,
#  4,
#  16,
#  9,
#  16,
#  13,
#  14,
#  8,
#  19,
#  14,
#  3,
#  12,
#  0,
#  15,
#  13,
#  0,
#  9,
#  7,
#  2,
#  1,
#  2,
#  14,
#  10,
#  7,
#  8,
#  1,
#  15,
#  15,
#  2,
#  6,
#  19,
#  8,
#  12,
#  5,
#  2,
#  15,
#  4,
#  0,
#  11,
#  16,
#  10,
#  6,
#  18,
#  18,
#  10,
#  10,
#  6,
#  6,
#  11,
#  3,
#  14,
#  15,
#  8,
#  9,
#  5,
#  0,
#  19,
#  12,
#  5,
#  7,
#  8,
#  14,
#  13,
#  3,
#  8,
#  1,
#  5,
#  3,
#  2,
#  6,
#  8,
#  7,
#  0,
#  7,
#  5,
#  0,
#  1,
#  11,
#  7,
#  16,
#  12,
#  1,
#  7,
#  13,
#  18,
#  18,
#  1,
#  3,
#  15,
#  14,
#  8,
#  11,
#  4,
#  12,
#  17,
#  12,
#  19,
#  2,
#  3,
#  9,
#  6,
#  15,
#  8,
#  17,
#  16,
#  18,
#  1,
#  4,
#  8,
#  10,
#  6,
#  13,
#  13,
#  13,
#  0,
#  6,
#  0,
#  18,
#  10,
#  19,
#  17,
#  ...]
# [11,
#  15,
#  4,
#  14,
#  1,
#  5,
#  18,
#  3,
#  10,
#  11,
#  5,
#  17,
#  2,
#  9,
#  10,
#  5,
#  18,
#  8,
#  16,
#  10,
#  16,
#  17,
#  2,
#  5,
#  17,
#  6,
#  12,
#  17,
#  8,
#  12,
#  18,
#  9,
#  17,
#  16,
#  11,
#  5,
#  19,
#  14,
#  7,
#  6,
#  15,
#  13,
#  10,
#  8,
#  17,
#  9,
#  14,
#  18,
#  19,
#  15,
#  1,
#  7,
#  5,
#  3,
#  10,
#  7,
#  17,
#  6,
#  14,
#  17,
#  16,
#  0,
#  0,
#  8,
#  4,
#  14,
#  4,
#  10,
#  15,
#  4,
#  2,
#  16,
#  11,
#  19,
#  16,
#  7,
#  19,
#  14,
#  10,
#  8,
#  5,
#  12,
#  12,
#  11,
#  10,
#  8,
#  12,
#  13,
#  10,
#  7,
#  14,
#  11,
#  14,
#  19,
#  0,
#  4,
#  12,
#  13,
#  1,
#  15,
#  0,
#  5,
#  0,
#  8,
#  3,
#  15,
#  4,
#  19,
#  17,
#  6,
#  17,
#  12,
#  6,
#  0,
#  14,
#  10,
#  9,
#  11,
#  6,
#  10,
#  12,
#  1,
#  14,
#  4,
#  8,
#  1,
#  2,
#  12,
#  4,
#  12,
#  18,
#  17,
#  5,
#  0,
#  6,
#  0,
#  12,
#  11,
#  9,
#  5,
#  17,
#  2,
#  14,
#  12,
#  5,
#  0,
#  13,
#  12,
#  16,
#  4,
#  13,
#  0,
#  18,
#  15,
#  10,
#  15,
#  5,
#  13,
#  1,
#  14,
#  12,
#  3,
#  19,
#  1,
#  2,
#  15,
#  5,
#  2,
#  3,
#  12,
#  16,
#  0,
#  11,
#  12,
#  2,
#  0,
#  4,
#  15,
#  7,
#  9,
#  11,
#  14,
#  11,
#  3,
#  13,
#  13,
#  19,
#  13,
#  14,
#  8,
#  14,
#  1,
#  16,
#  9,
#  16,
#  18,
#  19,
#  6,
#  5,
#  19,
#  5,
#  1,
#  14,
#  14,
#  10,
#  12,
#  8,
#  7,
#  10,
#  9,
#  16,
#  19,
#  9,
#  13,
#  16,
#  11,
#  13,
#  9,
#  5,
#  18,
#  3,
#  2,
#  5,
#  5,
#  11,
#  2,
#  5,
#  3,
#  14,
#  19,
#  18,
#  18,
#  13,
#  12,
#  19,
#  11,
#  13,
#  5,
#  15,
#  5,
#  18,
#  6,
#  14,
#  11,
#  3,
#  17,
#  2,
#  16,
#  5,
#  5,
#  8,
#  18,
#  18,
#  4,
#  14,
#  10,
#  10,
#  19,
#  17,
#  14,
#  14,
#  0,
#  8,
#  5,
#  12,
#  12,
#  7,
#  14,
#  12,
#  17,
#  4,
#  1,
#  15,
#  14,
#  2,
#  10,
#  18,
#  17,
#  11,
#  9,
#  12,
#  3,
#  1,
#  4,
#  1,
#  6,
#  18,
#  15,
#  7,
#  6,
#  7,
#  19,
#  16,
#  16,
#  9,
#  16,
#  12,
#  13,
#  18,
#  4,
#  10,
#  13,
#  8,
#  19,
#  4,
#  15,
#  11,
#  3,
#  14,
#  7,
#  8,
#  4,
#  8,
#  1,
#  2,
#  3,
#  8,
#  4,
#  2,
#  6,
#  9,
#  10,
#  0,
#  14,
#  2,
#  6,
#  12,
#  12,
#  3,
#  12,
#  2,
#  4,
#  5,
#  12,
#  12,
#  1,
#  2,
#  8,
#  8,
#  9,
#  16,
#  5,
#  8,
#  15,
#  8,
#  9,
#  1,
#  17,
#  10,
#  17,
#  6,
#  11,
#  2,
#  4,
#  11,
#  14,
#  16,
#  12,
#  9,
#  10,
#  8,
#  16,
#  2,
#  13,
#  13,
#  16,
#  0,
#  14,
#  11,
#  11,
#  18,
#  9,
#  1,
#  10,
#  5,
#  13,
#  11,
#  7,
#  18,
#  4,
#  0,
#  19,
#  14,
#  8,
#  19,
#  3,
#  8,
#  14,
#  6,
#  0,
#  18,
#  15,
#  18,
#  7,
#  1,
#  8,
#  16,
#  17,
#  3,
#  15,
#  0,
#  14,
#  4,
#  5,
#  18,
#  5,
#  17,
#  7,
#  18,
#  6,
#  8,
#  13,
#  11,
#  7,
#  4,
#  9,
#  10,
#  19,
#  17,
#  2,
#  7,
#  18,
#  13,
#  10,
#  5,
#  17,
#  1,
#  18,
#  8,
#  7,
#  11,
#  9,
#  16,
#  3,
#  10,
#  12,
#  10,
#  7,
#  0,
#  12,
#  7,
#  4,
#  17,
#  10,
#  12,
#  2,
#  15,
#  13,
#  12,
#  1,
#  6,
#  18,
#  18,
#  15,
#  9,
#  14,
#  2,
#  13,
#  8,
#  4,
#  2,
#  12,
#  10,
#  16,
#  6,
#  18,
#  2,
#  10,
#  3,
#  3,
#  15,
#  17,
#  2,
#  3,
#  8,
#  6,
#  11,
#  19,
#  5,
#  10,
#  19,
#  7,
#  7,
#  8,
#  5,
#  11,
#  0,
#  17,
#  0,
#  19,
#  14,
#  8,
#  7,
#  14,
#  10,
#  19,
#  5,
#  4,
#  2,
#  15,
#  19,
#  17,
#  1,
#  19,
#  13,
#  0,
#  9,
#  7,
#  1,
#  6,
#  2,
#  2,
#  10,
#  4,
#  16,
#  10,
#  10,
#  17,
#  19,
#  5,
#  11,
#  19,
#  9,
#  8,
#  2,
#  13,
#  10,
#  15,
#  4,
#  11,
#  8,
#  8,
#  3,
#  11,
#  10,
#  6,
#  16,
#  12,
#  6,
#  13,
#  18,
#  10,
#  6,
#  1,
#  3,
#  0,
#  1,
#  0,
#  4,
#  1,
#  10,
#  5,
#  13,
#  19,
#  19,
#  19,
#  13,
#  17,
#  4,
#  14,
#  18,
#  16,
#  14,
#  14,
#  0,
#  16,
#  9,
#  17,
#  10,
#  6,
#  19,
#  6,
#  2,
#  3,
#  10,
#  18,
#  18,
#  11,
#  14,
#  1,
#  14,
#  16,
#  2,
#  10,
#  18,
#  12,
#  4,
#  4,
#  9,
#  13,
#  4,
#  2,
#  4,
#  11,
#  16,
#  1,
#  3,
#  14,
#  14,
#  14,
#  5,
#  11,
#  17,
#  19,
#  5,
#  9,
#  7,
#  2,
#  9,
#  0,
#  17,
#  6,
#  8,
#  1,
#  14,
#  16,
#  8,
#  10,
#  7,
#  10,
#  6,
#  7,
#  13,
#  15,
#  9,
#  2,
#  6,
#  12,
#  1,
#  17,
#  19,
#  4,
#  5,
#  19,
#  13,
#  6,
#  6,
#  14,
#  0,
#  19,
#  13,
#  5,
#  13,
#  1,
#  17,
#  16,
#  4,
#  6,
#  16,
#  2,
#  2,
#  0,
#  10,
#  10,
#  19,
#  13,
#  1,
#  14,
#  4,
#  7,
#  3,
#  15,
#  15,
#  18,
#  8,
#  16,
#  14,
#  6,
#  5,
#  0,
#  3,
#  4,
#  14,
#  19,
#  6,
#  19,
#  2,
#  15,
#  15,
#  8,
#  10,
#  4,
#  18,
#  11,
#  16,
#  4,
#  11,
#  17,
#  6,
#  17,
#  16,
#  1,
#  14,
#  9,
#  18,
#  13,
#  9,
#  16,
#  12,
#  3,
#  9,
#  7,
#  0,
#  6,
#  17,
#  9,
#  6,
#  14,
#  11,
#  6,
#  6,
#  15,
#  12,
#  4,
#  7,
#  1,
#  16,
#  9,
#  15,
#  2,
#  19,
#  6,
#  14,
#  18,
#  12,
#  0,
#  11,
#  2,
#  16,
#  11,
#  15,
#  17,
#  1,
#  8,
#  1,
#  5,
#  19,
#  2,
#  10,
#  2,
#  14,
#  19,
#  8,
#  2,
#  8,
#  14,
#  18,
#  5,
#  16,
#  3,
#  12,
#  2,
#  4,
#  9,
#  6,
#  10,
#  4,
#  15,
#  13,
#  19,
#  4,
#  3,
#  11,
#  7,
#  6,
#  9,
#  6,
#  14,
#  2,
#  15,
#  15,
#  13,
#  11,
#  4,
#  16,
#  9,
#  17,
#  12,
#  15,
#  5,
#  9,
#  3,
#  0,
#  19,
#  16,
#  18,
#  18,
#  17,
#  2,
#  4,
#  12,
#  18,
#  4,
#  15,
#  12,
#  14,
#  4,
#  12,
#  19,
#  7,
#  12,
#  0,
#  16,
#  19,
#  6,
#  7,
#  18,
#  3,
#  8,
#  17,
#  9,
#  9,
#  8,
#  12,
#  10,
#  5,
#  12,
#  13,
#  11,
#  10,
#  0,
#  13,
#  4,
#  10,
#  0,
#  0,
#  12,
#  9,
#  14,
#  12,
#  17,
#  19,
#  12,
#  12,
#  10,
#  16,
#  13,
#  2,
#  7,
#  18,
#  16,
#  16,
#  13,
#  3,
#  10,
#  9,
#  13,
#  17,
#  16,
#  17,
#  19,
#  19,
#  11,
#  5,
#  16,
#  14,
#  10,
#  16,
#  6,
#  1,
#  14,
#  4,
#  9,
#  13,
#  2,
#  16,
#  12,
#  0,
#  9,
#  1,
#  11,
#  2,
#  5,
#  19,
#  4,
#  7,
#  11,
#  6,
#  14,
#  14,
#  4,
#  16,
#  9,
#  16,
#  13,
#  14,
#  8,
#  19,
#  14,
#  3,
#  12,
#  0,
#  15,
#  13,
#  0,
#  9,
#  7,
#  2,
#  1,
#  2,
#  14,
#  10,
#  7,
#  8,
#  1,
#  15,
#  15,
#  2,
#  6,
#  19,
#  8,
#  12,
#  5,
#  2,
#  15,
#  4,
#  0,
#  11,
#  16,
#  10,
#  6,
#  18,
#  18,
#  10,
#  10,
#  6,
#  6,
#  11,
#  3,
#  14,
#  15,
#  8,
#  9,
#  5,
#  0,
#  19,
#  12,
#  5,
#  7,
#  8,
#  14,
#  13,
#  3,
#  8,
#  1,
#  5,
#  3,
#  2,
#  6,
#  8,
#  7,
#  0,
#  7,
#  5,
#  0,
#  1,
#  11,
#  7,
#  16,
#  12,
#  1,
#  7,
#  13,
#  18,
#  18,
#  1,
#  3,
#  15,
#  14,
#  8,
#  11,
#  4,
#  12,
#  17,
#  12,
#  19,
#  2,
#  3,
#  9,
#  6,
#  15,
#  8,
#  17,
#  16,
#  18,
#  1,
#  4,
#  8,
#  10,
#  6,
#  13,
#  13,
#  13,
#  0,
#  6,
#  0,
#  18,
#  10,
#  19,
#  17,
#  ...]

# %%
data['fine_labels']
# Out:
# [19,
#  29,
#  0,
#  11,
#  1,
#  86,
#  90,
#  28,
#  23,
#  31,
#  39,
#  96,
#  82,
#  17,
#  71,
#  39,
#  8,
#  97,
#  80,
#  71,
#  74,
#  59,
#  70,
#  87,
#  59,
#  84,
#  64,
#  52,
#  42,
#  64,
#  8,
#  17,
#  47,
#  65,
#  21,
#  22,
#  81,
#  11,
#  24,
#  84,
#  78,
#  45,
#  49,
#  97,
#  56,
#  76,
#  11,
#  90,
#  89,
#  78,
#  73,
#  14,
#  87,
#  9,
#  71,
#  6,
#  47,
#  20,
#  98,
#  47,
#  36,
#  55,
#  72,
#  43,
#  51,
#  35,
#  83,
#  33,
#  27,
#  53,
#  92,
#  50,
#  15,
#  89,
#  36,
#  18,
#  89,
#  46,
#  33,
#  42,
#  39,
#  64,
#  75,
#  38,
#  23,
#  42,
#  66,
#  77,
#  49,
#  18,
#  46,
#  15,
#  35,
#  69,
#  95,
#  83,
#  75,
#  99,
#  73,
#  93,
#  55,
#  39,
#  4,
#  97,
#  61,
#  93,
#  51,
#  69,
#  56,
#  84,
#  59,
#  64,
#  94,
#  4,
#  11,
#  33,
#  68,
#  38,
#  20,
#  33,
#  34,
#  32,
#  46,
#  53,
#  88,
#  67,
#  70,
#  64,
#  53,
#  64,
#  8,
#  96,
#  87,
#  30,
#  20,
#  30,
#  66,
#  19,
#  76,
#  87,
#  52,
#  62,
#  35,
#  63,
#  40,
#  4,
#  99,
#  63,
#  74,
#  53,
#  26,
#  95,
#  48,
#  27,
#  33,
#  29,
#  39,
#  79,
#  32,
#  46,
#  64,
#  28,
#  85,
#  32,
#  82,
#  78,
#  39,
#  54,
#  28,
#  66,
#  65,
#  72,
#  21,
#  64,
#  62,
#  72,
#  0,
#  44,
#  7,
#  12,
#  19,
#  11,
#  31,
#  61,
#  79,
#  45,
#  81,
#  79,
#  98,
#  43,
#  46,
#  67,
#  80,
#  68,
#  74,
#  48,
#  81,
#  94,
#  86,
#  69,
#  39,
#  73,
#  2,
#  46,
#  49,
#  63,
#  43,
#  14,
#  49,
#  68,
#  65,
#  41,
#  37,
#  45,
#  36,
#  21,
#  77,
#  37,
#  39,
#  8,
#  9,
#  62,
#  86,
#  39,
#  19,
#  54,
#  39,
#  28,
#  11,
#  89,
#  90,
#  90,
#  79,
#  66,
#  81,
#  21,
#  79,
#  40,
#  29,
#  22,
#  13,
#  25,
#  11,
#  38,
#  10,
#  96,
#  54,
#  65,
#  39,
#  40,
#  42,
#  48,
#  48,
#  51,
#  11,
#  23,
#  23,
#  89,
#  52,
#  46,
#  2,
#  95,
#  43,
#  86,
#  34,
#  66,
#  18,
#  46,
#  66,
#  56,
#  57,
#  1,
#  44,
#  11,
#  82,
#  23,
#  90,
#  56,
#  19,
#  68,
#  66,
#  28,
#  1,
#  57,
#  67,
#  5,
#  13,
#  78,
#  6,
#  84,
#  7,
#  41,
#  65,
#  80,
#  12,
#  50,
#  63,
#  26,
#  8,
#  53,
#  60,
#  99,
#  97,
#  85,
#  0,
#  78,
#  31,
#  10,
#  2,
#  7,
#  43,
#  83,
#  97,
#  91,
#  82,
#  28,
#  42,
#  0,
#  82,
#  5,
#  68,
#  60,
#  30,
#  98,
#  82,
#  20,
#  64,
#  66,
#  10,
#  75,
#  54,
#  57,
#  87,
#  66,
#  66,
#  73,
#  54,
#  88,
#  42,
#  37,
#  80,
#  87,
#  3,
#  29,
#  43,
#  12,
#  73,
#  96,
#  23,
#  96,
#  84,
#  19,
#  62,
#  0,
#  21,
#  11,
#  36,
#  64,
#  76,
#  60,
#  3,
#  80,
#  82,
#  79,
#  26,
#  65,
#  72,
#  11,
#  15,
#  31,
#  48,
#  12,
#  91,
#  71,
#  87,
#  77,
#  15,
#  7,
#  58,
#  51,
#  55,
#  85,
#  2,
#  3,
#  89,
#  10,
#  3,
#  11,
#  20,
#  4,
#  48,
#  27,
#  48,
#  7,
#  67,
#  3,
#  65,
#  56,
#  9,
#  44,
#  95,
#  46,
#  83,
#  40,
#  58,
#  87,
#  59,
#  18,
#  48,
#  5,
#  88,
#  26,
#  21,
#  24,
#  53,
#  68,
#  49,
#  89,
#  96,
#  92,
#  7,
#  13,
#  99,
#  49,
#  22,
#  56,
#  67,
#  13,
#  97,
#  6,
#  19,
#  76,
#  65,
#  9,
#  71,
#  63,
#  71,
#  18,
#  55,
#  34,
#  18,
#  0,
#  56,
#  23,
#  75,
#  70,
#  78,
#  45,
#  66,
#  91,
#  25,
#  58,
#  90,
#  29,
#  68,
#  35,
#  54,
#  77,
#  97,
#  0,
#  70,
#  75,
#  60,
#  65,
#  5,
#  58,
#  82,
#  49,
#  61,
#  28,
#  44,
#  56,
#  82,
#  61,
#  43,
#  20,
#  38,
#  85,
#  87,
#  49,
#  85,
#  24,
#  7,
#  88,
#  40,
#  38,
#  72,
#  56,
#  4,
#  81,
#  98,
#  97,
#  14,
#  46,
#  23,
#  89,
#  86,
#  83,
#  54,
#  27,
#  41,
#  96,
#  1,
#  81,
#  79,
#  30,
#  17,
#  14,
#  67,
#  20,
#  54,
#  92,
#  33,
#  57,
#  65,
#  49,
#  71,
#  59,
#  85,
#  22,
#  31,
#  85,
#  17,
#  42,
#  62,
#  26,
#  60,
#  27,
#  57,
#  19,
#  97,
#  88,
#  10,
#  31,
#  23,
#  84,
#  74,
#  63,
#  94,
#  77,
#  90,
#  60,
#  5,
#  1,
#  61,
#  95,
#  32,
#  95,
#  57,
#  32,
#  23,
#  39,
#  45,
#  41,
#  69,
#  89,
#  45,
#  47,
#  57,
#  11,
#  48,
#  74,
#  2,
#  11,
#  95,
#  50,
#  37,
#  59,
#  71,
#  84,
#  89,
#  84,
#  70,
#  16,
#  71,
#  8,
#  48,
#  31,
#  98,
#  32,
#  2,
#  74,
#  62,
#  71,
#  90,
#  34,
#  51,
#  0,
#  12,
#  26,
#  57,
#  62,
#  57,
#  31,
#  65,
#  32,
#  16,
#  35,
#  98,
#  11,
#  87,
#  38,
#  52,
#  89,
#  40,
#  76,
#  7,
#  54,
#  76,
#  30,
#  59,
#  84,
#  3,
#  91,
#  46,
#  65,
#  43,
#  49,
#  6,
#  33,
#  5,
#  14,
#  77,
#  44,
#  68,
#  82,
#  94,
#  66,
#  73,
#  56,
#  89,
#  53,
#  22,
#  69,
#  77,
#  84,
#  20,
#  98,
#  4,
#  69,
#  79,
#  40,
#  45,
#  1,
#  56,
#  65,
#  51,
#  5,
#  80,
#  54,
#  92,
#  4,
#  23,
#  60,
#  81,
#  77,
#  73,
#  98,
#  0,
#  14,
#  9,
#  44,
#  27,
#  8,
#  43,
#  74,
#  46,
#  94,
#  86,
#  30,
#  61,
#  57,
#  11,
#  81,
#  25,
#  81,
#  70,
#  29,
#  27,
#  3,
#  71,
#  53,
#  48,
#  19,
#  80,
#  57,
#  19,
#  59,
#  25,
#  56,
#  74,
#  32,
#  98,
#  37,
#  13,
#  45,
#  12,
#  80,
#  64,
#  16,
#  17,
#  24,
#  30,
#  25,
#  96,
#  37,
#  5,
#  98,
#  31,
#  94,
#  5,
#  29,
#  66,
#  51,
#  6,
#  67,
#  50,
#  68,
#  27,
#  62,
#  89,
#  5,
#  11,
#  13,
#  66,
#  55,
#  15,
#  62,
#  74,
#  31,
#  93,
#  59,
#  1,
#  97,
#  32,
#  39,
#  41,
#  62,
#  71,
#  70,
#  98,
#  41,
#  42,
#  70,
#  3,
#  35,
#  90,
#  22,
#  50,
#  61,
#  66,
#  92,
#  53,
#  12,
#  84,
#  33,
#  57,
#  93,
#  79,
#  69,
#  53,
#  9,
#  19,
#  6,
#  20,
#  76,
#  5,
#  98,
#  92,
#  78,
#  93,
#  79,
#  21,
#  51,
#  74,
#  76,
#  56,
#  75,
#  27,
#  22,
#  37,
#  16,
#  72,
#  81,
#  36,
#  48,
#  13,
#  56,
#  70,
#  0,
#  63,
#  90,
#  53,
#  29,
#  64,
#  2,
#  83,
#  63,
#  89,
#  14,
#  66,
#  95,
#  65,
#  85,
#  5,
#  7,
#  58,
#  61,
#  42,
#  59,
#  37,
#  12,
#  42,
#  66,
#  71,
#  40,
#  63,
#  45,
#  19,
#  33,
#  55,
#  26,
#  0,
#  60,
#  72,
#  4,
#  63,
#  76,
#  46,
#  64,
#  96,
#  69,
#  64,
#  75,
#  33,
#  36,
#  26,
#  62,
#  18,
#  48,
#  50,
#  36,
#  26,
#  28,
#  71,
#  76,
#  45,
#  52,
#  65,
#  59,
#  41,
#  69,
#  15,
#  87,
#  50,
#  11,
#  71,
#  36,
#  84,
#  73,
#  46,
#  83,
#  12,
#  79,
#  54,
#  50,
#  75,
#  72,
#  37,
#  91,
#  19,
#  82,
#  22,
#  41,
#  53,
#  14,
#  15,
#  84,
#  11,
#  35,
#  83,
#  36,
#  17,
#  74,
#  26,
#  46,
#  97,
#  85,
#  98,
#  10,
#  63,
#  72,
#  93,
#  45,
#  95,
#  68,
#  14,
#  62,
#  73,
#  62,
#  11,
#  23,
#  24,
#  97,
#  32,
#  78,
#  29,
#  54,
#  20,
#  41,
#  88,
#  34,
#  87,
#  62,
#  29,
#  0,
#  4,
#  31,
#  50,
#  33,
#  5,
#  8,
#  48,
#  71,
#  71,
#  94,
#  5,
#  15,
#  16,
#  98,
#  29,
#  42,
#  68,
#  40,
#  95,
#  85,
#  64,
#  40,
#  24,
#  3,
#  11,
#  79,
#  10,
#  3,
#  73,
#  22,
#  28,
#  70,
#  94,
#  42,
#  14,
#  4,
#  18,
#  86,
#  4,
#  32,
#  38,
#  24,
#  65,
#  75,
#  1,
#  7,
#  99,
#  58,
#  8,
#  67,
#  10,
#  44,
#  98,
#  88,
#  31,
#  83,
#  63,
#  59,
#  34,
#  81,
#  54,
#  28,
#  76,
#  84,
#  44,
#  88,
#  59,
#  65,
#  8,
#  91,
#  51,
#  42,
#  23,
#  20,
#  26,
#  77,
#  77,
#  4,
#  84,
#  4,
#  8,
#  60,
#  41,
#  96,
#  ...]
# [19,
#  29,
#  0,
#  11,
#  1,
#  86,
#  90,
#  28,
#  23,
#  31,
#  39,
#  96,
#  82,
#  17,
#  71,
#  39,
#  8,
#  97,
#  80,
#  71,
#  74,
#  59,
#  70,
#  87,
#  59,
#  84,
#  64,
#  52,
#  42,
#  64,
#  8,
#  17,
#  47,
#  65,
#  21,
#  22,
#  81,
#  11,
#  24,
#  84,
#  78,
#  45,
#  49,
#  97,
#  56,
#  76,
#  11,
#  90,
#  89,
#  78,
#  73,
#  14,
#  87,
#  9,
#  71,
#  6,
#  47,
#  20,
#  98,
#  47,
#  36,
#  55,
#  72,
#  43,
#  51,
#  35,
#  83,
#  33,
#  27,
#  53,
#  92,
#  50,
#  15,
#  89,
#  36,
#  18,
#  89,
#  46,
#  33,
#  42,
#  39,
#  64,
#  75,
#  38,
#  23,
#  42,
#  66,
#  77,
#  49,
#  18,
#  46,
#  15,
#  35,
#  69,
#  95,
#  83,
#  75,
#  99,
#  73,
#  93,
#  55,
#  39,
#  4,
#  97,
#  61,
#  93,
#  51,
#  69,
#  56,
#  84,
#  59,
#  64,
#  94,
#  4,
#  11,
#  33,
#  68,
#  38,
#  20,
#  33,
#  34,
#  32,
#  46,
#  53,
#  88,
#  67,
#  70,
#  64,
#  53,
#  64,
#  8,
#  96,
#  87,
#  30,
#  20,
#  30,
#  66,
#  19,
#  76,
#  87,
#  52,
#  62,
#  35,
#  63,
#  40,
#  4,
#  99,
#  63,
#  74,
#  53,
#  26,
#  95,
#  48,
#  27,
#  33,
#  29,
#  39,
#  79,
#  32,
#  46,
#  64,
#  28,
#  85,
#  32,
#  82,
#  78,
#  39,
#  54,
#  28,
#  66,
#  65,
#  72,
#  21,
#  64,
#  62,
#  72,
#  0,
#  44,
#  7,
#  12,
#  19,
#  11,
#  31,
#  61,
#  79,
#  45,
#  81,
#  79,
#  98,
#  43,
#  46,
#  67,
#  80,
#  68,
#  74,
#  48,
#  81,
#  94,
#  86,
#  69,
#  39,
#  73,
#  2,
#  46,
#  49,
#  63,
#  43,
#  14,
#  49,
#  68,
#  65,
#  41,
#  37,
#  45,
#  36,
#  21,
#  77,
#  37,
#  39,
#  8,
#  9,
#  62,
#  86,
#  39,
#  19,
#  54,
#  39,
#  28,
#  11,
#  89,
#  90,
#  90,
#  79,
#  66,
#  81,
#  21,
#  79,
#  40,
#  29,
#  22,
#  13,
#  25,
#  11,
#  38,
#  10,
#  96,
#  54,
#  65,
#  39,
#  40,
#  42,
#  48,
#  48,
#  51,
#  11,
#  23,
#  23,
#  89,
#  52,
#  46,
#  2,
#  95,
#  43,
#  86,
#  34,
#  66,
#  18,
#  46,
#  66,
#  56,
#  57,
#  1,
#  44,
#  11,
#  82,
#  23,
#  90,
#  56,
#  19,
#  68,
#  66,
#  28,
#  1,
#  57,
#  67,
#  5,
#  13,
#  78,
#  6,
#  84,
#  7,
#  41,
#  65,
#  80,
#  12,
#  50,
#  63,
#  26,
#  8,
#  53,
#  60,
#  99,
#  97,
#  85,
#  0,
#  78,
#  31,
#  10,
#  2,
#  7,
#  43,
#  83,
#  97,
#  91,
#  82,
#  28,
#  42,
#  0,
#  82,
#  5,
#  68,
#  60,
#  30,
#  98,
#  82,
#  20,
#  64,
#  66,
#  10,
#  75,
#  54,
#  57,
#  87,
#  66,
#  66,
#  73,
#  54,
#  88,
#  42,
#  37,
#  80,
#  87,
#  3,
#  29,
#  43,
#  12,
#  73,
#  96,
#  23,
#  96,
#  84,
#  19,
#  62,
#  0,
#  21,
#  11,
#  36,
#  64,
#  76,
#  60,
#  3,
#  80,
#  82,
#  79,
#  26,
#  65,
#  72,
#  11,
#  15,
#  31,
#  48,
#  12,
#  91,
#  71,
#  87,
#  77,
#  15,
#  7,
#  58,
#  51,
#  55,
#  85,
#  2,
#  3,
#  89,
#  10,
#  3,
#  11,
#  20,
#  4,
#  48,
#  27,
#  48,
#  7,
#  67,
#  3,
#  65,
#  56,
#  9,
#  44,
#  95,
#  46,
#  83,
#  40,
#  58,
#  87,
#  59,
#  18,
#  48,
#  5,
#  88,
#  26,
#  21,
#  24,
#  53,
#  68,
#  49,
#  89,
#  96,
#  92,
#  7,
#  13,
#  99,
#  49,
#  22,
#  56,
#  67,
#  13,
#  97,
#  6,
#  19,
#  76,
#  65,
#  9,
#  71,
#  63,
#  71,
#  18,
#  55,
#  34,
#  18,
#  0,
#  56,
#  23,
#  75,
#  70,
#  78,
#  45,
#  66,
#  91,
#  25,
#  58,
#  90,
#  29,
#  68,
#  35,
#  54,
#  77,
#  97,
#  0,
#  70,
#  75,
#  60,
#  65,
#  5,
#  58,
#  82,
#  49,
#  61,
#  28,
#  44,
#  56,
#  82,
#  61,
#  43,
#  20,
#  38,
#  85,
#  87,
#  49,
#  85,
#  24,
#  7,
#  88,
#  40,
#  38,
#  72,
#  56,
#  4,
#  81,
#  98,
#  97,
#  14,
#  46,
#  23,
#  89,
#  86,
#  83,
#  54,
#  27,
#  41,
#  96,
#  1,
#  81,
#  79,
#  30,
#  17,
#  14,
#  67,
#  20,
#  54,
#  92,
#  33,
#  57,
#  65,
#  49,
#  71,
#  59,
#  85,
#  22,
#  31,
#  85,
#  17,
#  42,
#  62,
#  26,
#  60,
#  27,
#  57,
#  19,
#  97,
#  88,
#  10,
#  31,
#  23,
#  84,
#  74,
#  63,
#  94,
#  77,
#  90,
#  60,
#  5,
#  1,
#  61,
#  95,
#  32,
#  95,
#  57,
#  32,
#  23,
#  39,
#  45,
#  41,
#  69,
#  89,
#  45,
#  47,
#  57,
#  11,
#  48,
#  74,
#  2,
#  11,
#  95,
#  50,
#  37,
#  59,
#  71,
#  84,
#  89,
#  84,
#  70,
#  16,
#  71,
#  8,
#  48,
#  31,
#  98,
#  32,
#  2,
#  74,
#  62,
#  71,
#  90,
#  34,
#  51,
#  0,
#  12,
#  26,
#  57,
#  62,
#  57,
#  31,
#  65,
#  32,
#  16,
#  35,
#  98,
#  11,
#  87,
#  38,
#  52,
#  89,
#  40,
#  76,
#  7,
#  54,
#  76,
#  30,
#  59,
#  84,
#  3,
#  91,
#  46,
#  65,
#  43,
#  49,
#  6,
#  33,
#  5,
#  14,
#  77,
#  44,
#  68,
#  82,
#  94,
#  66,
#  73,
#  56,
#  89,
#  53,
#  22,
#  69,
#  77,
#  84,
#  20,
#  98,
#  4,
#  69,
#  79,
#  40,
#  45,
#  1,
#  56,
#  65,
#  51,
#  5,
#  80,
#  54,
#  92,
#  4,
#  23,
#  60,
#  81,
#  77,
#  73,
#  98,
#  0,
#  14,
#  9,
#  44,
#  27,
#  8,
#  43,
#  74,
#  46,
#  94,
#  86,
#  30,
#  61,
#  57,
#  11,
#  81,
#  25,
#  81,
#  70,
#  29,
#  27,
#  3,
#  71,
#  53,
#  48,
#  19,
#  80,
#  57,
#  19,
#  59,
#  25,
#  56,
#  74,
#  32,
#  98,
#  37,
#  13,
#  45,
#  12,
#  80,
#  64,
#  16,
#  17,
#  24,
#  30,
#  25,
#  96,
#  37,
#  5,
#  98,
#  31,
#  94,
#  5,
#  29,
#  66,
#  51,
#  6,
#  67,
#  50,
#  68,
#  27,
#  62,
#  89,
#  5,
#  11,
#  13,
#  66,
#  55,
#  15,
#  62,
#  74,
#  31,
#  93,
#  59,
#  1,
#  97,
#  32,
#  39,
#  41,
#  62,
#  71,
#  70,
#  98,
#  41,
#  42,
#  70,
#  3,
#  35,
#  90,
#  22,
#  50,
#  61,
#  66,
#  92,
#  53,
#  12,
#  84,
#  33,
#  57,
#  93,
#  79,
#  69,
#  53,
#  9,
#  19,
#  6,
#  20,
#  76,
#  5,
#  98,
#  92,
#  78,
#  93,
#  79,
#  21,
#  51,
#  74,
#  76,
#  56,
#  75,
#  27,
#  22,
#  37,
#  16,
#  72,
#  81,
#  36,
#  48,
#  13,
#  56,
#  70,
#  0,
#  63,
#  90,
#  53,
#  29,
#  64,
#  2,
#  83,
#  63,
#  89,
#  14,
#  66,
#  95,
#  65,
#  85,
#  5,
#  7,
#  58,
#  61,
#  42,
#  59,
#  37,
#  12,
#  42,
#  66,
#  71,
#  40,
#  63,
#  45,
#  19,
#  33,
#  55,
#  26,
#  0,
#  60,
#  72,
#  4,
#  63,
#  76,
#  46,
#  64,
#  96,
#  69,
#  64,
#  75,
#  33,
#  36,
#  26,
#  62,
#  18,
#  48,
#  50,
#  36,
#  26,
#  28,
#  71,
#  76,
#  45,
#  52,
#  65,
#  59,
#  41,
#  69,
#  15,
#  87,
#  50,
#  11,
#  71,
#  36,
#  84,
#  73,
#  46,
#  83,
#  12,
#  79,
#  54,
#  50,
#  75,
#  72,
#  37,
#  91,
#  19,
#  82,
#  22,
#  41,
#  53,
#  14,
#  15,
#  84,
#  11,
#  35,
#  83,
#  36,
#  17,
#  74,
#  26,
#  46,
#  97,
#  85,
#  98,
#  10,
#  63,
#  72,
#  93,
#  45,
#  95,
#  68,
#  14,
#  62,
#  73,
#  62,
#  11,
#  23,
#  24,
#  97,
#  32,
#  78,
#  29,
#  54,
#  20,
#  41,
#  88,
#  34,
#  87,
#  62,
#  29,
#  0,
#  4,
#  31,
#  50,
#  33,
#  5,
#  8,
#  48,
#  71,
#  71,
#  94,
#  5,
#  15,
#  16,
#  98,
#  29,
#  42,
#  68,
#  40,
#  95,
#  85,
#  64,
#  40,
#  24,
#  3,
#  11,
#  79,
#  10,
#  3,
#  73,
#  22,
#  28,
#  70,
#  94,
#  42,
#  14,
#  4,
#  18,
#  86,
#  4,
#  32,
#  38,
#  24,
#  65,
#  75,
#  1,
#  7,
#  99,
#  58,
#  8,
#  67,
#  10,
#  44,
#  98,
#  88,
#  31,
#  83,
#  63,
#  59,
#  34,
#  81,
#  54,
#  28,
#  76,
#  84,
#  44,
#  88,
#  59,
#  65,
#  8,
#  91,
#  51,
#  42,
#  23,
#  20,
#  26,
#  77,
#  77,
#  4,
#  84,
#  4,
#  8,
#  60,
#  41,
#  96,
#  ...]

# %%
data['data']
# Out:
# array([[255, 255, 255, ...,  10,  59,  79],
#        [255, 253, 253, ..., 253, 253, 255],
#        [250, 248, 247, ..., 194, 207, 228],
#        ...,
#        [248, 240, 236, ..., 180, 174, 205],
#        [156, 151, 151, ..., 114, 107, 126],
#        [ 31,  30,  31, ...,  72,  69,  67]], dtype=uint8)
# array([[255, 255, 255, ...,  10,  59,  79],
#        [255, 253, 253, ..., 253, 253, 255],
#        [250, 248, 247, ..., 194, 207, 228],
#        ...,
#        [248, 240, 236, ..., 180, 174, 205],
#        [156, 151, 151, ..., 114, 107, 126],
#        [ 31,  30,  31, ...,  72,  69,  67]], dtype=uint8)

# %% [markdown]
# Assign training data: We first train on the coarse lables

# %%
x_train = data['data'].reshape((len(data['data']), 3, 32, 32)).transpose(0, 2, 3, 1)
y_train = data['coarse_labels']

# %% [markdown]
# ### Load testing set

# %%
with open(data_path + 'test', mode='rb') as f2:
    test_data = pickle.load(f2, encoding='latin1')
    x_test = test_data['data'].reshape((len(test_data['data']), 3, 32, 32)).transpose(0, 2, 3, 1)
    y_test = test_data['coarse_labels']

# %% [markdown]
# ## Preprocessing

# %%
from sklearn.preprocessing import MinMaxScaler
minmax = MinMaxScaler()

# Reshaping
x_train_rows = x_train.reshape(x_train.shape[0], 32 * 32 * 3)
x_test_rows = x_test.reshape(x_test.shape[0], 32 * 32 * 3)

# Normalizing
x_train = minmax.fit_transform(x_train_rows)
x_test = minmax.fit_transform(x_test_rows)

# Reshaping
x_train = x_train.reshape(x_train.shape[0], 32, 32, 3)
x_test = x_test.reshape(x_test.shape[0], 32, 32, 3)

# %% [markdown]
# One-hot Coding

# %%
from sklearn.preprocessing import LabelBinarizer
n_class = 20
lb = LabelBinarizer().fit(np.array(range(n_class)))

y_train = lb.transform(y_train)
y_test = lb.transform(y_test)

# %% [markdown]
# Train set and validation set

# %%
from sklearn.model_selection import train_test_split

train_ratio = 0.8 # train ratio
x_train_, x_val, y_train_, y_val = train_test_split(x_train, 
                                                    y_train, 
                                                    train_size=train_ratio,
                                                    random_state=219)#random seed

# %% [markdown]
# ## Set up the network

# %%
img_shape = x_train.shape
keep_prob = 0.6
epochs=2
batch_size=16

# %%
inputs_ = tf.placeholder(tf.float32, [None, 32, 32, 3], name='inputs_')
targets_ = tf.placeholder(tf.float32, [None, n_class], name='targets_')

# %%
# 第一层卷积加池化
# 32 x 32 x 3 to 32 x 32 x 64
conv1 = tf.layers.conv2d(inputs_, 16, (2,2), padding='same', activation=tf.nn.relu, 
                         kernel_initializer=tf.truncated_normal_initializer(mean=0.0, stddev=0.1))
# 32 x 32 x 64 to 16 x 16 x 64
conv1 = tf.layers.max_pooling2d(conv1, (2,2), (2,2), padding='same')

# 第二层卷积加池化
# 16 x 16 x 64 to 16 x 16 x 128
conv2 = tf.layers.conv2d(conv1, 32, (4,4), padding='same', activation=tf.nn.relu,
                         kernel_initializer=tf.truncated_normal_initializer(mean=0.0, stddev=0.1))
# 16 x 16 x 128 to 8 x 8 x 128
conv2 = tf.layers.max_pooling2d(conv2, (2,2), (2,2), padding='same')

# 重塑输出
shape = np.prod(conv2.get_shape().as_list()[1:])
conv2 = tf.reshape(conv2,[-1, shape])

# 第一层全连接层
# 8 x 8 x 128 to 1 x 1024
fc1 = tf.contrib.layers.fully_connected(conv2, 128, activation_fn=tf.nn.relu)
fc1 = tf.nn.dropout(fc1, keep_prob)

# 第二层全连接层
# 1 x 1024 to 1 x 512
fc2 = tf.contrib.layers.fully_connected(fc1, 64, activation_fn=tf.nn.relu)

# logits层
# 1 x 512 to 1 x 20
logits_ = tf.contrib.layers.fully_connected(fc2, n_class, activation_fn=None)
logits_ = tf.identity(logits_, name='logits_')

# cost & optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits_, labels=targets_))
optimizer = tf.train.AdamOptimizer(0.01).minimize(cost)

# accuracy
correct_pred = tf.equal(tf.argmax(logits_, 1), tf.argmax(targets_, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

# %%
import time
start_time=time.time()
save_model_path='./test_cifar'
count = 0
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    
    for epoch in range(epochs):
        for batch_i in range(img_shape[0]//batch_size-1):
            feature_batch = x_train_[batch_i * batch_size: (batch_i+1)*batch_size]
            label_batch = y_train_[batch_i * batch_size: (batch_i+1)*batch_size]
            train_loss, _ = sess.run([cost, optimizer],
                                     feed_dict={inputs_: feature_batch,
                                                targets_: label_batch})

            val_acc = sess.run(accuracy,
                               feed_dict={inputs_: x_val,
                                          targets_: y_val})
            
            if(count%n_class==0):
                print('Epoch {:>2}, Train Loss {:.4f}, Validation Accuracy {:4f} '.format(epoch + 1, train_loss, val_acc))
            now_time=time.time()
            complete_percent=100*(batch_i+1)*(epoch+1)/(epochs*(img_shape[0]//batch_size-1))
            print('%1.4f%% completed. Time elapsed:%6d seconds. ETA:%6.0f hours.'%((complete_percent),now_time-start_time,((now_time-start_time)*100/complete_percent)/3600)
            count += 1
    
    # 存储参数
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Epoch  1, Train Loss 2.9553, Validation Accuracy 0.052700
# 0.0160% completed. Time elapsed:     3. ETA: 24556
# Epoch  1, Train Loss 2.9553, Validation Accuracy 0.052700
# 0.0160% completed. Time elapsed:     3. ETA: 24556
# 0.0320% completed. Time elapsed:     5. ETA: 17039
# 0.0320% completed. Time elapsed:     5. ETA: 17039
# 0.0480% completed. Time elapsed:     6. ETA: 14517
# 0.0480% completed. Time elapsed:     6. ETA: 14517
# 0.0640% completed. Time elapsed:     8. ETA: 13205
# 0.0640% completed. Time elapsed:     8. ETA: 13205
# 0.0800% completed. Time elapsed:    10. ETA: 12510
# 0.0800% completed. Time elapsed:    10. ETA: 12510
# 0.0960% completed. Time elapsed:    11. ETA: 12233
# 0.0960% completed. Time elapsed:    11. ETA: 12233
# 0.1120% completed. Time elapsed:    13. ETA: 11827
# 0.1120% completed. Time elapsed:    13. ETA: 11827
# 0.1280% completed. Time elapsed:    14. ETA: 11584
# 0.1280% completed. Time elapsed:    14. ETA: 11584
# 0.1440% completed. Time elapsed:    16. ETA: 11409
# 0.1440% completed. Time elapsed:    16. ETA: 11409
# 0.1601% completed. Time elapsed:    17. ETA: 11209
# 0.1601% completed. Time elapsed:    17. ETA: 11209
# 0.1761% completed. Time elapsed:    19. ETA: 11055
# 0.1761% completed. Time elapsed:    19. ETA: 11055
# 0.1921% completed. Time elapsed:    20. ETA: 10896
# 0.1921% completed. Time elapsed:    20. ETA: 10896
# 0.2081% completed. Time elapsed:    22. ETA: 10745
# 0.2081% completed. Time elapsed:    22. ETA: 10745
# 0.2241% completed. Time elapsed:    23. ETA: 10607
# 0.2241% completed. Time elapsed:    23. ETA: 10607
# 0.2401% completed. Time elapsed:    25. ETA: 10527
# 0.2401% completed. Time elapsed:    25. ETA: 10527
# 0.2561% completed. Time elapsed:    26. ETA: 10526
# 0.2561% completed. Time elapsed:    26. ETA: 10526
# 0.2721% completed. Time elapsed:    28. ETA: 10554
# 0.2721% completed. Time elapsed:    28. ETA: 10554
# 0.2881% completed. Time elapsed:    30. ETA: 10480
# 0.2881% completed. Time elapsed:    30. ETA: 10480
# 0.3041% completed. Time elapsed:    31. ETA: 10398
# 0.3041% completed. Time elapsed:    31. ETA: 10398
# 0.3201% completed. Time elapsed:    33. ETA: 10499
# 0.3201% completed. Time elapsed:    33. ETA: 10499
# Epoch  1, Train Loss 2.9878, Validation Accuracy 0.048400
# 0.3361% completed. Time elapsed:    35. ETA: 10432
# Epoch  1, Train Loss 2.9878, Validation Accuracy 0.048400
# 0.3361% completed. Time elapsed:    35. ETA: 10432
# 0.3521% completed. Time elapsed:    36. ETA: 10374
# 0.3521% completed. Time elapsed:    36. ETA: 10374
# 0.3681% completed. Time elapsed:    38. ETA: 10341
# 0.3681% completed. Time elapsed:    38. ETA: 10341
# 0.3841% completed. Time elapsed:    39. ETA: 10292
# 0.3841% completed. Time elapsed:    39. ETA: 10292
# 0.4001% completed. Time elapsed:    41. ETA: 10252
# 0.4001% completed. Time elapsed:    41. ETA: 10252
# 0.4161% completed. Time elapsed:    42. ETA: 10224
# 0.4161% completed. Time elapsed:    42. ETA: 10224
# 0.4321% completed. Time elapsed:    44. ETA: 10192
# 0.4321% completed. Time elapsed:    44. ETA: 10192
# 0.4481% completed. Time elapsed:    45. ETA: 10162
# 0.4481% completed. Time elapsed:    45. ETA: 10162
# 0.4641% completed. Time elapsed:    46. ETA: 10114
# 0.4641% completed. Time elapsed:    46. ETA: 10114
# 0.4802% completed. Time elapsed:    48. ETA: 10075
# 0.4802% completed. Time elapsed:    48. ETA: 10075
# 0.4962% completed. Time elapsed:    49. ETA: 10051
# 0.4962% completed. Time elapsed:    49. ETA: 10051
# 0.5122% completed. Time elapsed:    51. ETA: 10034
# 0.5122% completed. Time elapsed:    51. ETA: 10034
# 0.5282% completed. Time elapsed:    53. ETA: 10036
# 0.5282% completed. Time elapsed:    53. ETA: 10036
# 0.5442% completed. Time elapsed:    54. ETA: 10000
# 0.5442% completed. Time elapsed:    54. ETA: 10000
# 0.5602% completed. Time elapsed:    55. ETA:  9975
# 0.5602% completed. Time elapsed:    55. ETA:  9975
# 0.5762% completed. Time elapsed:    57. ETA:  9948
# 0.5762% completed. Time elapsed:    57. ETA:  9948
# 0.5922% completed. Time elapsed:    58. ETA:  9925
# 0.5922% completed. Time elapsed:    58. ETA:  9925
# 0.6082% completed. Time elapsed:    60. ETA:  9907
# 0.6082% completed. Time elapsed:    60. ETA:  9907
# 0.6242% completed. Time elapsed:    61. ETA:  9891
# 0.6242% completed. Time elapsed:    61. ETA:  9891
# 0.6402% completed. Time elapsed:    63. ETA:  9874
# 0.6402% completed. Time elapsed:    63. ETA:  9874
# Epoch  1, Train Loss 2.9709, Validation Accuracy 0.048400
# 0.6562% completed. Time elapsed:    64. ETA:  9853
# Epoch  1, Train Loss 2.9709, Validation Accuracy 0.048400
# 0.6562% completed. Time elapsed:    64. ETA:  9853
# 0.6722% completed. Time elapsed:    66. ETA:  9834
# 0.6722% completed. Time elapsed:    66. ETA:  9834
# 0.6882% completed. Time elapsed:    67. ETA:  9809
# 0.6882% completed. Time elapsed:    67. ETA:  9809
# 0.7042% completed. Time elapsed:    68. ETA:  9790
# 0.7042% completed. Time elapsed:    68. ETA:  9790
# 0.7202% completed. Time elapsed:    70. ETA:  9769
# 0.7202% completed. Time elapsed:    70. ETA:  9769
# 0.7362% completed. Time elapsed:    71. ETA:  9751
# 0.7362% completed. Time elapsed:    71. ETA:  9751
# 0.7522% completed. Time elapsed:    73. ETA:  9727
# 0.7522% completed. Time elapsed:    73. ETA:  9727
# 0.7682% completed. Time elapsed:    74. ETA:  9702
# 0.7682% completed. Time elapsed:    74. ETA:  9702
# 0.7843% completed. Time elapsed:    75. ETA:  9679
# 0.7843% completed. Time elapsed:    75. ETA:  9679
# 0.8003% completed. Time elapsed:    77. ETA:  9660
# 0.8003% completed. Time elapsed:    77. ETA:  9660
# 0.8163% completed. Time elapsed:    78. ETA:  9666
# 0.8163% completed. Time elapsed:    78. ETA:  9666
# 0.8323% completed. Time elapsed:    80. ETA:  9659
# 0.8323% completed. Time elapsed:    80. ETA:  9659
# 0.8483% completed. Time elapsed:    82. ETA:  9697
# 0.8483% completed. Time elapsed:    82. ETA:  9697
# 0.8643% completed. Time elapsed:    84. ETA:  9757
# 0.8643% completed. Time elapsed:    84. ETA:  9757
# 0.8803% completed. Time elapsed:    86. ETA:  9797
# 0.8803% completed. Time elapsed:    86. ETA:  9797
# 0.8963% completed. Time elapsed:    87. ETA:  9795
# 0.8963% completed. Time elapsed:    87. ETA:  9795
# 0.9123% completed. Time elapsed:    89. ETA:  9789
# 0.9123% completed. Time elapsed:    89. ETA:  9789
# 0.9283% completed. Time elapsed:    90. ETA:  9778
# 0.9283% completed. Time elapsed:    90. ETA:  9778
# 0.9443% completed. Time elapsed:    92. ETA:  9767
# 0.9443% completed. Time elapsed:    92. ETA:  9767
# 0.9603% completed. Time elapsed:    93. ETA:  9773
# 0.9603% completed. Time elapsed:    93. ETA:  9773
# Epoch  1, Train Loss 2.9640, Validation Accuracy 0.048300
# 0.9763% completed. Time elapsed:    95. ETA:  9776
# Epoch  1, Train Loss 2.9640, Validation Accuracy 0.048300
# 0.9763% completed. Time elapsed:    95. ETA:  9776
# 0.9923% completed. Time elapsed:    96. ETA:  9770
# 0.9923% completed. Time elapsed:    96. ETA:  9770
# 1.0083% completed. Time elapsed:    98. ETA:  9763
# 1.0083% completed. Time elapsed:    98. ETA:  9763
# 1.0243% completed. Time elapsed:    99. ETA:  9757
# 1.0243% completed. Time elapsed:    99. ETA:  9757
# 1.0403% completed. Time elapsed:   101. ETA:  9749
# 1.0403% completed. Time elapsed:   101. ETA:  9749
# 1.0563% completed. Time elapsed:   102. ETA:  9738
# 1.0563% completed. Time elapsed:   102. ETA:  9738
# 1.0723% completed. Time elapsed:   104. ETA:  9727
# 1.0723% completed. Time elapsed:   104. ETA:  9727
# 1.0883% completed. Time elapsed:   105. ETA:  9718
# 1.0883% completed. Time elapsed:   105. ETA:  9718
# 1.1044% completed. Time elapsed:   107. ETA:  9711
# 1.1044% completed. Time elapsed:   107. ETA:  9711
# 1.1204% completed. Time elapsed:   108. ETA:  9697
# 1.1204% completed. Time elapsed:   108. ETA:  9697
# 1.1364% completed. Time elapsed:   110. ETA:  9684
# 1.1364% completed. Time elapsed:   110. ETA:  9684
# 1.1524% completed. Time elapsed:   111. ETA:  9679
# 1.1524% completed. Time elapsed:   111. ETA:  9679
# 1.1684% completed. Time elapsed:   112. ETA:  9669
# 1.1684% completed. Time elapsed:   112. ETA:  9669
# 1.1844% completed. Time elapsed:   114. ETA:  9660
# 1.1844% completed. Time elapsed:   114. ETA:  9660
# 1.2004% completed. Time elapsed:   115. ETA:  9651
# 1.2004% completed. Time elapsed:   115. ETA:  9651
# 1.2164% completed. Time elapsed:   117. ETA:  9637
# 1.2164% completed. Time elapsed:   117. ETA:  9637
# 1.2324% completed. Time elapsed:   118. ETA:  9626
# 1.2324% completed. Time elapsed:   118. ETA:  9626
# 1.2484% completed. Time elapsed:   120. ETA:  9613
# 1.2484% completed. Time elapsed:   120. ETA:  9613
# 1.2644% completed. Time elapsed:   121. ETA:  9600
# 1.2644% completed. Time elapsed:   121. ETA:  9600
# 1.2804% completed. Time elapsed:   122. ETA:  9589
# 1.2804% completed. Time elapsed:   122. ETA:  9589
# Epoch  1, Train Loss 3.0261, Validation Accuracy 0.048500
# 1.2964% completed. Time elapsed:   124. ETA:  9577
# Epoch  1, Train Loss 3.0261, Validation Accuracy 0.048500
# 1.2964% completed. Time elapsed:   124. ETA:  9577
# 1.3124% completed. Time elapsed:   125. ETA:  9566
# 1.3124% completed. Time elapsed:   125. ETA:  9566
# 1.3284% completed. Time elapsed:   126. ETA:  9553
# 1.3284% completed. Time elapsed:   126. ETA:  9553
# 1.3444% completed. Time elapsed:   128. ETA:  9545
# 1.3444% completed. Time elapsed:   128. ETA:  9545
# 1.3604% completed. Time elapsed:   129. ETA:  9535
# 1.3604% completed. Time elapsed:   129. ETA:  9535
# 1.3764% completed. Time elapsed:   131. ETA:  9525
# 1.3764% completed. Time elapsed:   131. ETA:  9525
# 1.3924% completed. Time elapsed:   132. ETA:  9518
# 1.3924% completed. Time elapsed:   132. ETA:  9518
# 1.4085% completed. Time elapsed:   133. ETA:  9511
# 1.4085% completed. Time elapsed:   133. ETA:  9511
# 1.4245% completed. Time elapsed:   135. ETA:  9507
# 1.4245% completed. Time elapsed:   135. ETA:  9507

# %% [markdown]
# ## Results on test set

# %%
import random

# %%
loaded_graph = tf.Graph()
test_batch_size= 100
with tf.Session(graph=loaded_graph) as sess:
    # 加载模型
    loader = tf.train.import_meta_graph(data_path + 'meta')
    loader.restore(sess, save_model_path)

    # 加载tensor
    loaded_x = loaded_graph.get_tensor_by_name('inputs_:0')
    loaded_y = loaded_graph.get_tensor_by_name('targets_:0')
    loaded_logits = loaded_graph.get_tensor_by_name('logits_:0')
    loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')

    # 计算test的准确率
    test_batch_acc_total = 0
    test_batch_count = 0
    
    print("Begin test...")
    for batch_i in range(x_test.shape[0]//test_batch_size-1):
        test_feature_batch = x_test[batch_i * test_batch_size: (batch_i+1)*test_batch_size]
        test_label_batch = y_test[batch_i * test_batch_size: (batch_i+1)*test_batch_size]
        test_batch_acc_total += sess.run(
            loaded_acc,
            feed_dict={loaded_x: test_feature_batch, loaded_y: test_label_batch})
        test_batch_count += 1

    print('Test Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))
